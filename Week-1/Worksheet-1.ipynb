# %% [markdown]
# # Worksheet 1

# %% [markdown]
# ## Question 1

# %%
import numpy as np

# %%
random_arr = np.random.randint(1,high=100,size=(5,5))
print(random_arr)
# Out:
# [[40 25  6 92 93]
#  [91 35 46 23 45]
#  [13 70 17  7 54]
#  [91 82 77 55 57]
#  [24 99  9 71 60]]

# %% [markdown]
# ### Part A

# %%
middle_element = random_arr[2][2]
print(middle_element)
# Out:
# 17

# %% [markdown]
# ### Part B

# %%
row_mean = np.mean(random_arr, axis = 1,dtype=np.float64)
print(row_mean)
# Out:
# [51.2 48.  32.2 72.4 52.6]

# %% [markdown]
# ### Part C

# %%
mean = np.mean(random_arr,dtype=np.float64)
print(mean)
# Out:
# 51.28

# %%
mask = random_arr > mean
mean_arr = random_arr[mask]
print(mean_arr)
# Out:
# [92 93 91 70 54 91 82 77 55 57 99 71 60]

# %% [markdown]
# ### Part D

# %%
def spiral_order(arr):
    row = len(arr)
    col = len(arr[0])
    ans = []
    top ,bottom ,left ,right = 0, row, 0, col
    while top < bottom and left < right : 

        # top row
        for i in range (left,right):
            ans.append(arr[top][i])
        top += 1

        # right column
        for i in range (top,bottom):
            ans.append(arr[i][right - 1])
        right -= 1

        # bottom row
        if top < bottom :
            for i in range (right - 1, left - 1, -1):
                ans.append(arr[bottom - 1][i])
            bottom -= 1

        #left row
        if left < right :
            for i in range (bottom - 1, top - 1, -1):
                ans.append(arr[i][left])
            left += 1
            
    return ans

# %%
spiral_list = spiral_order(random_arr.tolist())
spiral_list
print(spiral_list)
# Out:
# [40, 25, 6, 92, 93, 45, 54, 57, 60, 71, 9, 99, 24, 91, 13, 91, 35, 46, 23, 7, 55, 77, 82, 70, 17]

# %% [markdown]
# ## Question 2

# %%
import pandas as pd

# %%
df = pd.read_csv('./videogamesales.csv')
df
# Out:
#                                              Name Platform    Year     Genre  \
# 0                                       Asteroids     2600  1980.0   Shooter
# 1                                 Missile Command     2600  1980.0   Shooter
# 2                                         Kaboom!     2600  1980.0      Misc
# 3                                        Defender     2600  1980.0      Misc
# 4                                          Boxing     2600  1980.0  Fighting
# ...                                           ...      ...     ...       ...
# 16578           WRC: FIA World Rally Championship     X360     NaN    Racing
# 16579           WRC: FIA World Rally Championship       PC     NaN    Racing
# 16580  Writing and Speaking Beautiful Japanese DS       DS     NaN      Misc
# 16581  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     NaN    Racing
# 16582                    Zero: Tsukihami no Kamen      Wii     NaN    Action
#
# ...

# %% [markdown]
# ### Part A

# %%
df['Global_Sales'] = df.iloc[:,-4:].sum(axis = 1)
df = df.sort_values(by='Global_Sales', ascending = False)
df
# Out:
#                                                    Name Platform    Year  \
# 6109                                         Wii Sports      Wii  2006.0
# 122                                   Super Mario Bros.      NES  1985.0
# 8315                                     Mario Kart Wii      Wii  2008.0
# 9743                                  Wii Sports Resort      Wii  2009.0
# 705                            Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 10978       Military History: Commander - Europe at War       DS  2009.0
# 7971            Puzzle Quest: Challenge of the Warlords      PSP  2007.0
# 7972                         Race Driver: Create & Race       DS  2007.0
# 10854                                   Cross Edge Dash     X360  2009.0
# 9650   SCORE International Baja 1000: The Official Game      PS2  2008.0
#
#               Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Part B

# %%
import matplotlib.pyplot as plt

# %%
genre_sales = df.groupby('Genre')['Global_Sales'].sum()
genre_sales
# Out:
# Genre
# Action          1745.92
# Adventure        238.81
# Fighting         448.94
# Misc             809.30
# Platform         831.04
# Puzzle           244.42
# Racing           731.77
# Role-Playing     923.82
# Shooter         1036.84
# Simulation       391.91
# Sports          1330.54
# Strategy         174.86
# Name: Global_Sales, dtype: float64

# %%
genre_sales.plot(kind='bar', figsize=(10,5))
plt.ylabel('Total Global Sales')
plt.show()

# %% [markdown]
# ### Part C

# %%
filter_df = df[df['Name'].str.contains('Grand Theft Auto')]
filter_df
# Out:
#                                                     Name Platform    Year  \
# 14223                                 Grand Theft Auto V      PS3  2013.0
# 4405                       Grand Theft Auto: San Andreas      PS2  2004.0
# 14222                                 Grand Theft Auto V     X360  2013.0
# 2805                         Grand Theft Auto: Vice City      PS2  2002.0
# 2323                                Grand Theft Auto III      PS2  2001.0
# 14769                                 Grand Theft Auto V      PS4  2014.0
# 8316                                 Grand Theft Auto IV     X360  2008.0
# 8319                                 Grand Theft Auto IV      PS3  2008.0
# 5173              Grand Theft Auto: Liberty City Stories      PSP  2005.0
# 6125                 Grand Theft Auto: Vice City Stories      PSP  2006.0
# 14775                                 Grand Theft Auto V     XOne  2014.0
# 6128              Grand Theft Auto: Liberty City Stories      PS2  2006.0
# ...

# %%
gta_df = filter_df[['Name','Platform','Year']].copy()
gta_df['Sales'] = filter_df['EU_Sales'] + filter_df['JP_Sales']
gta_df
# Out:
#                                                     Name Platform    Year  \
# 14223                                 Grand Theft Auto V      PS3  2013.0
# 4405                       Grand Theft Auto: San Andreas      PS2  2004.0
# 14222                                 Grand Theft Auto V     X360  2013.0
# 2805                         Grand Theft Auto: Vice City      PS2  2002.0
# 2323                                Grand Theft Auto III      PS2  2001.0
# 14769                                 Grand Theft Auto V      PS4  2014.0
# 8316                                 Grand Theft Auto IV     X360  2008.0
# 8319                                 Grand Theft Auto IV      PS3  2008.0
# 5173              Grand Theft Auto: Liberty City Stories      PSP  2005.0
# 6125                 Grand Theft Auto: Vice City Stories      PSP  2006.0
# 14775                                 Grand Theft Auto V     XOne  2014.0
# 6128              Grand Theft Auto: Liberty City Stories      PS2  2006.0
# ...

# %% [markdown]
# ### Part D

# %%
gta_sales_df = filter_df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum().to_frame().T
gta_sales_df
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0     73.81     54.78      3.77        29.26

# %%
gta_sales_df.iloc[0].plot(kind = 'pie')
# Out:
# <Axes: >
